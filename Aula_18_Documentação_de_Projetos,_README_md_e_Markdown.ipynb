# %% [markdown]
# <a href="https://colab.research.google.com/github/WellingtonRoque/ALP/blob/main/Aula_18_Documenta%C3%A7%C3%A3o_de_Projetos%2C_README_md_e_Markdown.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🚀 Algoritmos e Lógica de Programação
# # Aula 18 — Documentação de Projetos, README.md e Markdown
#
# ---
#
# # 🎯 Objetivos da Aula
#
# Nesta aula os alunos irão:
#
# ✅ compreender documentação de software
# ✅ criar arquivos README.md
# ✅ utilizar Markdown
# ✅ organizar projetos profissionais
# ✅ documentar sistemas corretamente
# ✅ evoluir o projeto do semestre

# %% [markdown]
# # 💡 Estrutura da Aula
#
# ## 🔹 Parte 1
# Revisão da aula anterior
#
# ## 🔹 Parte 2
# Importância da documentação
#
# ## 🔹 Parte 3
# Markdown
#
# ## 🔹 Parte 4
# Estrutura de README.md
#
# ## 🔹 Parte 5
# Documentação profissional
#
# ## 🔹 Parte 6
# Projeto do semestre
#
# ## 🔹 Parte 7
# Prática guiada
#
# ## 🔹 Parte 8
# Exercícios

# %% [markdown]
# # 🌐 Parte 1 — Revisão da Aula Anterior
#
# Na aula passada aprendemos:
#
# ✅ Git
# ✅ GitHub
# ✅ versionamento
# ✅ commits
# ✅ publicação de projetos

# %% [markdown]
# # 🧠 Parte 2 — Importância da Documentação
#
# # 📖 O que é documentação?
#
# Documentação é o conjunto de informações que explicam um projeto.

# %% [markdown]
# # 💡 Por que documentar?
#
# ✅ facilitar manutenção
# ✅ facilitar uso do sistema
# ✅ organização profissional
# ✅ facilitar trabalho em equipe

# %% [markdown]
# # 💡 Sistemas profissionais possuem documentação
#
# ✅ APIs
# ✅ sistemas web
# ✅ ERPs
# ✅ bibliotecas
# ✅ aplicações corporativas

# %% [markdown]
# # 📖 O que é README.md?
#
# Arquivo principal de apresentação do projeto.

# %% [markdown]
# # 💻 Exemplo de estrutura
#
# ```plaintext
# README.md
# ```

# %% [markdown]
# # 🧠 Parte 3 — Markdown
#
# # 📖 O que é Markdown?
#
# Linguagem simples para formatação de textos.

# %% [markdown]
# # 💻 Títulos

# %%
# Título 1

## Título 2

### Título 3

# %% [markdown]
# # 💻 Texto em negrito

# %%
**Texto em negrito**

# %% [markdown]
# # 💻 Listas

# %%
- item 1
- item 2
- item 3

# %% [markdown]
# # 💻 Links

# %%
[GitHub](https://github.com)

# %% [markdown]
# # 💻 Blocos de código

# %%
```python
print("Olá Mundo")
```

# %% [markdown]
# # 🧠 Parte 4 — Estrutura de README.md
#
# # 💡 Estrutura recomendada

# %% [markdown]
# # 📖 Informações importantes
#
# ✅ nome do projeto
# ✅ descrição
# ✅ funcionalidades
# ✅ tecnologias utilizadas
# ✅ como executar
# ✅ autor

# %% [markdown]
# # 💻 Exemplo de README

# %%
# Sistema de Gestão Comercial

Sistema desenvolvido em Python.

## Funcionalidades

- Cadastro de produtos
- Cadastro de clientes
- Relatórios

## Tecnologias

- Python
- Git
- GitHub

# %% [markdown]
# # 💻 Adicionando imagens

# %%
![Imagem](imagem.png)

# %% [markdown]
# # 💻 Adicionando emojis

# %%
# 🚀 Projeto Python

# %% [markdown]
# # 🧠 Parte 5 — Documentação Profissional
#
# # 💡 Projetos profissionais precisam de organização

# %% [markdown]
# # 📖 Estrutura profissional
#
# ```plaintext
# Projeto/
#
# ├── app.py
# ├── README.md
# ├── requirements.txt
# ├── imagens/
# └── dados/
# ```

# %% [markdown]
# # 💻 Exemplo de descrição profissional

# %%
Sistema desenvolvido para gerenciamento comercial utilizando Python.

# %% [markdown]
# # 💻 Exemplo de funcionalidades

# %%
## Funcionalidades

- Cadastro de produtos
- Controle de estoque
- Relatórios
- Persistência de dados

# %% [markdown]
# # 💻 Exemplo de execução

# %%
python app.py

# %% [markdown]
# # 🛒 Parte 6 — Projeto do Semestre
#
# # 📦 Sistema de Gestão Comercial
#
# Hoje iremos documentar o projeto completo.

# %% [markdown]
# # 💻 README do projeto

# %%
# 🚀 Sistema de Gestão Comercial

Sistema desenvolvido na disciplina de Algoritmos e Lógica de Programação.

## 📚 Funcionalidades

- Cadastro de produtos
- Cadastro de clientes
- Controle de estoque
- Relatórios

## 🛠 Tecnologias

- Python
- Git
- GitHub

## ▶ Como executar

python app.py

# %% [markdown]
# # 💻 Estrutura final do projeto

# %%
Projeto/

├── app.py
├── produtos.txt
├── clientes.txt
├── README.md
└── imagens/

# %% [markdown]
# # 🚀 Evolução futura
#
# Nas próximas aulas iremos adicionar:
#
# ✅ deploy
# ✅ publicação online
# ✅ apresentação final do projeto

# %% [markdown]
# # 🧪 Parte 7 — Prática Guiada
#
# # 🔹 Exercício Guiado 1
#
# Criar título em Markdown.

# %%
# Meu Projeto

# %% [markdown]
# # 🔹 Exercício Guiado 2
#
# Criar lista de funcionalidades.

# %%
## Funcionalidades

- Cadastro
- Relatórios
- Estoque

# %% [markdown]
# # 🔹 Exercício Guiado 3
#
# Criar README básico do projeto.

# %%
# Sistema Comercial

Sistema desenvolvido em Python.

# %% [markdown]
# # 🧪 Parte 8 — Exercícios
#
# # 🔥 Exercício 1
#
# Criar README simples do projeto.

# %% [markdown]
# # 🔥 Exercício 2
#
# Adicionar funcionalidades ao README.

# %% [markdown]
# # 🔥 Exercício 3
#
# Adicionar tecnologias utilizadas.

# %% [markdown]
# # 🔥 Exercício 4
#
# Adicionar instruções de execução.

# %% [markdown]
# # 🔥 Exercício 5
#
# Adicionar emojis e formatação.

# %% [markdown]
# # 🚀 Exercícios Intermediários
#
# # 🔥 Exercício 6
#
# Criar documentação profissional do projeto.

# %% [markdown]
# # 🔥 Exercício 7
#
# Criar estrutura organizada de diretórios.

# %% [markdown]
# # 🔥 Exercício 8
#
# Adicionar imagens ao README.

# %% [markdown]
# # 🔥 Exercício 9
#
# Criar documentação completa do Sistema Comercial.

# %% [markdown]
# # 🔥 Exercício 10
#
# Evoluir o Sistema de Gestão Comercial adicionando:
#
# ✅ README profissional
# ✅ documentação organizada
# ✅ funcionalidades documentadas
# ✅ estrutura do projeto

# %% [markdown]
# # 🧠 Conceitos Aprendidos
#
# Nesta aula aprendemos:
#
# ✅ documentação
# ✅ README.md
# ✅ Markdown
# ✅ organização profissional
# ✅ apresentação de projetos

# %% [markdown]
# # 🚀 Próxima Aula
#
# Na próxima aula iremos aprender:
#
# ✅ deploy de aplicações
# ✅ Render
# ✅ publicação online
# ✅ apresentação final 👊
